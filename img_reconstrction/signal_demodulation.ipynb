# %%
import numpy as np
import imageio.v2 as imageio
import h5py
from scipy.signal import resample_poly, firwin, lfilter

# ---------- Parameters ----------
Fs_default = 61_440_000.0
pixel_rate = 148_500_000.0
h_total, v_total = 2200, 1125
up, down = 2475, 1024
BW = 16e6
numtaps = 129

file_in = './signals/sample_001_slide001_CF_742.500MHz_FS_61.440MSPS_T0.2s_20260403_124806.mat'
out_prefix = 'p3_6frames_vertical'
n_frames = 6


# ---------- data reading ----------
def dataset_to_complex(d):
    d = np.array(d)

    # Case A: Complex dtype
    if np.iscomplexobj(d):
        return d.squeeze().astype(np.complex64)

    # Case B: structured dtype, including real / imag
    if (
        isinstance(d.dtype, np.dtype)
        and d.dtype.fields is not None
        and {'real', 'imag'}.issubset(d.dtype.fields.keys())
    ):
        real = d['real']
        imag = d['imag']
        return (real + 1j * imag).astype(np.complex64).squeeze()

    # Case C: Nx2 or 2xN array of real numbers (I/Q interleaved)
    if d.ndim == 2 and d.shape[1] == 2:
        return (d[:, 0] + 1j * d[:, 1]).astype(np.complex64)
    if d.ndim == 2 and d.shape[0] == 2:
        return (d[0, :] + 1j * d[1, :]).astype(np.complex64)

    # Case D: single column or row of real numbers (assume real-only)
    if d.ndim == 2 and (d.shape[0] == 1 or d.shape[1] == 1):
        return d.flatten().astype(np.complex64)

    raise ValueError(
        f"Unsupported dataset shape or dtype: shape={d.shape}, dtype={d.dtype}"
    )


# ---------- File Reading ----------
def read_bb_or_mat(fname, Fs_fallback=None):
    meta = {}

    if fname.endswith('.mat'):
        with h5py.File(fname, 'r') as f:
            keys = list(f.keys())
            print('Top-level keys:', keys)

            # ===== Find IQ data =====
            if 'iq' in keys:
                rx = dataset_to_complex(f['iq'])
            elif 'x' in keys:
                rx = dataset_to_complex(f['x'])
            elif 'BasebandData' in keys and 'IQData' in f['BasebandData']:
                iq = np.array(f['BasebandData']['IQData'])
                rx = (iq[:, 0] + 1j * iq[:, 1]).astype(np.complex64)
            elif '/BasebandData/IQData' in f:
                iq = np.array(f['/BasebandData/IQData'])
                rx = (iq[:, 0] + 1j * iq[:, 1]).astype(np.complex64)
            else:
                raise ValueError(
                    "Cannot find dataset 'iq', 'x', or '/BasebandData/IQData'. "
                    f"Top keys: {keys}"
                )

            # ===== Try to read Fs / Fc and other metadata =====
            if 'Fs' in keys:
                meta['Fs'] = float(np.array(f['Fs']).squeeze())
            elif Fs_fallback is not None:
                meta['Fs'] = float(Fs_fallback)

            if 'Fc' in keys:
                meta['Fc'] = float(np.array(f['Fc']).squeeze())

            if 'capture_time_s' in keys:
                meta['capture_time_s'] = float(np.array(f['capture_time_s']).squeeze())

            if 'total_overrun' in keys:
                meta['total_overrun'] = int(np.array(f['total_overrun']).squeeze())

            return rx, meta

    elif fname.endswith('.bb'):
        with h5py.File(fname, 'r') as f:
            iq = np.array(f['/BasebandData/IQData'])
            rx = (iq[:, 0] + 1j * iq[:, 1]).astype(np.complex64)

        if Fs_fallback is not None:
            meta['Fs'] = float(Fs_fallback)

        return rx, meta

    else:
        raise ValueError('Unsupported file extension')


# ---------- Simple Frequency Offset Estimation ----------
def estimate_freq_offset(x, Fs, m=2000):
    if len(x) <= m:
        return 0.0
    r = x[m:] * np.conj(x[:-m])
    ang = np.angle(np.sum(r))
    return ang / (2 * np.pi * m / Fs)


# ---------- Save Complex IQ Visualization ----------
def save_iq_vis(img_complex, prefix):
    I = np.real(img_complex)
    Q = np.imag(img_complex)

    vmin, vmax = np.percentile(np.hstack((I.ravel(), Q.ravel())), (1, 99))
    if vmax <= vmin:
        vmax = vmin + 1e-6

    Ir = np.clip((I - vmin) / (vmax - vmin), 0, 1)
    Qr = np.clip((Q - vmin) / (vmax - vmin), 0, 1)

    vis = np.stack([Ir, Qr, np.zeros_like(Ir)], axis=-1)

    np.save(prefix + '.npy', img_complex)
    imageio.imwrite(prefix + '.png', (vis * 255).astype(np.uint8))


# ---------- Save Amplitude Variants ----------
def save_amp_variants(img_complex, prefix):
    amp = np.abs(img_complex)

    # Original amplitude (linear scale)
    vmin, vmax = np.percentile(amp, (1, 99))
    if vmax <= vmin:
        vmax = vmin + 1e-6
    amp_norm = np.clip((amp - vmin) / (vmax - vmin), 0, 1)
    imageio.imwrite(prefix + '_amp.png', (amp_norm * 255).astype(np.uint8))

    # Gain boost on linear amplitude
    GAIN = 3.0
    amp_boost = np.clip(amp_norm * GAIN, 0, 1)
    imageio.imwrite(prefix + '_amp_gain.png', (amp_boost * 255).astype(np.uint8))

    # Logarithmic amplitude with gain boost
    amp_db = 20 * np.log10(amp + 1e-8)
    vmin, vmax = np.percentile(amp_db, (1, 99))
    if vmax <= vmin:
        vmax = vmin + 1e-6
    amp_db_norm = np.clip((amp_db - vmin) / (vmax - vmin), 0, 1)
    GAIN_LOG = 1.4
    amp_db_boost = np.clip(amp_db_norm * GAIN_LOG, 0, 1)
    imageio.imwrite(prefix + '_amp_log_gain.png', (amp_db_boost * 255).astype(np.uint8))


# ===============================================================
# Main processing flow
# ===============================================================
rx, meta = read_bb_or_mat(file_in, Fs_fallback=Fs_default)

Fs = meta.get('Fs', Fs_default)
Fc = meta.get('Fc', None)

print(f'Loaded {len(rx)/1e6:.2f} M samples.')
print(f'Using Fs = {Fs/1e6:.6f} MSPS')
if Fc is not None:
    print(f'File Fc = {Fc/1e6:.3f} MHz')
if 'total_overrun' in meta:
    print(f"File total_overrun = {meta['total_overrun']}")

# ---------- Remove DC component ----------
rx = rx - np.mean(rx[:min(len(rx), 10000)])

# ---------- Simple Frequency Offset Estimation ----------
foff = estimate_freq_offset(rx, Fs)
print(f'Estimated freq offset: {foff:.1f} Hz')

n = np.arange(len(rx))
rx = rx * np.exp(-2j * np.pi * foff * n / Fs)

# ---------- Bandpass Filtering ----------
nyq = Fs / 2
b = firwin(numtaps, cutoff=BW / nyq)
rx_filt = lfilter(b, 1.0, rx)

# ---------- Resample to Pixel Rate ----------
rx_pix = resample_poly(rx_filt, up, down)
print(f'Resampled to {len(rx_pix)/1e6:.2f} M samples at {pixel_rate/1e6:.1f} MHz')

# ---------- Extract Continuous n_frames Frames ----------
Npix = h_total * v_total
need = n_frames * Npix

if len(rx_pix) < need:
    raise ValueError(
        f'Samples not enough for {n_frames} full frames: '
        f'need {need}, have {len(rx_pix)}'
    )

frames = []
for k in range(n_frames):
    seg = rx_pix[k * Npix : (k + 1) * Npix]
    img = seg.reshape((v_total, h_total))
    frames.append(img)

frames = np.stack(frames, axis=0)
print(f'Extracted frames shape: {frames.shape}')

# ---------- Vertical Stacking ----------
img_complex_stacked = np.vstack(frames)
print(f'Stacked image shape: {img_complex_stacked.shape}')

# ---------- Save Results ----------
save_iq_vis(img_complex_stacked, out_prefix)
save_amp_variants(img_complex_stacked, out_prefix)

print('Saved:')
print(f'  {out_prefix}.npy')
print(f'  {out_prefix}.png')
print(f'  {out_prefix}_amp.png')
print(f'  {out_prefix}_amp_gain.png')
print(f'  {out_prefix}_amp_log_gain.png')
# Out:
# C:\UserData\AppData\Local\Temp\ipykernel_24900\1873354107.py:24: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   d = np.array(f['x'])
# Loaded 6.00 M samples.
# Estimated freq offset: -7001.8 Hz
# Resampled to 14.85 M samples at 148.5 MHz
# Saved: image6_35db_v2.npy / .png
# Saved amplitude variants: _amp.png, _amp_gain.png, _amp_log_gain.png
